# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import sys

sys.path.append('../')


from modules.dataframeinfo import DataFrameInfo
from modules.data_transform import DataTransform, apply_powertransformations
from modules.dataframe_transform import DataFrameTransform, impute_all_null_columns, drop_outliers, drop_highly_correlated_columns

# %%
# Load Data
df = pd.read_csv("../csv_files/loan_payments.csv")

# %%
data_transform = DataTransform()
df_info_original = DataFrameInfo(df)

# %%
# Cast Datatypes
df = data_transform.encode_transform(df)
df = data_transform.transform_digit_string(df)
df = data_transform.cast_column_dtypes(df)
# Out:
# id --> int32
# member_id --> int32
# loan_amount --> int32
# funded_amount --> float32
# funded_amount_inv --> float32
# term --> int32
# int_rate --> float32
# instalment --> float32
# grade --> category
# sub_grade --> category
# employment_length --> int32
# home_ownership --> category
# annual_inc --> float32
# verification_status --> category
# issue_date --> date
# loan_status --> category
# payment_plan --> category
# purpose --> category
# dti --> float32
# delinq_2yrs --> int32
# earliest_credit_line --> date
# inq_last_6mths --> int32
# mths_since_last_delinq --> int32
# mths_since_last_record --> int32
# open_accounts --> int32
# total_accounts --> int32
# out_prncp --> float32
# out_prncp_inv --> float32
# total_payment --> float32
# total_payment_inv --> float32
# total_rec_prncp --> float32
# total_rec_int --> float32
# total_rec_late_fee --> float32
# recoveries --> float32
# collection_recovery_fee --> float32
# last_payment_date --> date
# last_payment_amount --> float32
# next_payment_date --> date
# last_credit_pull_date --> date
# collections_12_mths_ex_med --> int32
# mths_since_last_major_derog --> int32
# policy_code --> int32
# application_type --> category

# %%
# Impute columns that have null values
df = impute_all_null_columns(df)
# Out:
#                              number of nulls  percentage of nulls  \
# funded_amount                           3007                 5.54
# term                                    4772                 8.80
# int_rate                                5169                 9.53
# employment_length                       2118                 3.91
# mths_since_last_delinq                 31002                57.17
# mths_since_last_record                 48050                88.60
# collections_12_mths_ex_med                51                 0.09
# mths_since_last_major_derog            46732                86.17
#
#                              percentage of non-nulls
# funded_amount                                  94.46
# term                                           91.20
# int_rate                                       90.47
# employment_length                              96.09
# mths_since_last_delinq                         42.83
# mths_since_last_record                         11.40
# collections_12_mths_ex_med                     99.91
# mths_since_last_major_derog                    13.83
#
# Imputing null columns ....
#
# Empty DataFrame
# Columns: [number of nulls, percentage of nulls, percentage of non-nulls]
# Index: []

# %%
# APPLY THE TRANSFORMATIONS BASED OFF THE BEST POWER TRANSFORM METHOD FOR NORMALISATION
df = apply_powertransformations(df)
# Out:
# /home/vant28/.conda/envs/my_env/lib/python3.11/site-packages/numpy/core/_methods.py:152: RuntimeWarning: overflow encountered in reduce
#   arrmean = umr_sum(arr, axis, dtype, keepdims=True, where=where)
# /home/vant28/.conda/envs/my_env/lib/python3.11/site-packages/numpy/core/_methods.py:176: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# /home/vant28/.conda/envs/my_env/lib/python3.11/site-packages/numpy/core/_methods.py:187: RuntimeWarning: overflow encountered in reduce
#   ret = umr_sum(x, axis, dtype, out, keepdims=keepdims, where=where)

# %%
# Drop outliers
df = drop_outliers(df)

# %%
# Drop highly correlated columns
df_info_transformed = DataFrameInfo(df)
num_cols = df_info_transformed.numerical_columns[3:-2]
num_cols
df = drop_highly_correlated_columns(df,num_cols)
# Out:
# Over correlated columns: ['loan_amount', 'funded_amount', 'funded_amount_inv', 'instalment', 'out_prncp', 'out_prncp_inv', 'total_payment', 'total_payment_inv', 'total_rec_prncp', 'recoveries', 'collection_recovery_fee']

# %%
df
# Out:
#        Unnamed: 0        id  member_id  term  int_rate grade sub_grade  \
# 0               0  38676116   41461848  36.0  3.489637     A        A4
# 1               1  38656203   41440010  36.0  3.340711     A        A3
# 2               2  38656154   41439961  36.0  3.489637     A        A4
# 3               3  38656128   41439934  36.0  5.155342     C        C4
# 4               4  38656121   41439927  36.0  3.038983     A        A1
# ...           ...       ...        ...   ...       ...   ...       ...
# 54225       54225    115606      87310  36.0  5.299521     F        F1
# 54226       54226     76597      76583  36.0  3.913655     B        B2
# 54228       54228    117045      70978  36.0  3.472037     A        A2
# 54229       54229     88854      70699  36.0  3.472037     A        A2
# 54230       54230     72323      70694  36.0  4.544128     C        C5
#
#        employment_length home_ownership  annual_inc  ... open_accounts  \
# 0                    5.0       MORTGAGE     46000.0  ...            12
# 1                    9.0           RENT     50000.0  ...            15
# 2                    8.0       MORTGAGE     73913.0  ...             7
# 3                    0.0           RENT     42000.0  ...             6
# 4                    1.0       MORTGAGE    145000.0  ...            23
# ...                  ...            ...         ...  ...           ...
# 54225                0.0           RENT     18000.0  ...             2
# 54226                0.0       MORTGAGE    250000.0  ...             5
# 54228                1.0       MORTGAGE    300000.0  ...             8
# 54229                4.0           RENT    200000.0  ...             2
# 54230                9.0       MORTGAGE     55000.0  ...             6
#
#       total_accounts total_rec_int total_rec_late_fee last_payment_date  \
# 0                 27    512.210022                0.0        2022-01-01
# 1                 31    787.940002                0.0        2022-01-01
# 2                 18    824.539978                0.0        2021-10-01
# 3                 13    947.469971                0.0        2021-06-01
# 4                 50    770.929993                0.0        2022-01-01
# ...              ...           ...                ...               ...
# 54225              2   1558.739990                0.0        2014-07-01
# 54226              7    724.820007                0.0        2016-07-01
# 54228             18    415.369995                0.0        2016-09-01
# 54229              2    174.179993                0.0        2014-03-01
# 54230             13    352.339996                0.0        2014-03-01
#
#        last_payment_amount  last_credit_pull_date collections_12_mths_ex_med  \
# 0               248.820007             2022-01-01                        0.0
# 1               407.519989             2022-01-01                        0.0
# 2             12850.160156             2021-10-01                        0.0
# 3             13899.669922             2021-06-01                        0.0
# 4               456.540009             2022-01-01                        0.0
# ...                    ...                    ...                        ...
# 54225          9921.870117             2013-06-01                        0.0
# 54226           160.610001             2016-07-01                        0.0
# 54228           110.580002             2013-05-01                        0.0
# 54229             0.000000             2013-05-01                        0.0
# 54230           164.970001             2015-01-01                        0.0
#
#        policy_code  application_type
# 0                1        INDIVIDUAL
# 1                1        INDIVIDUAL
# 2                1        INDIVIDUAL
# 3                1        INDIVIDUAL
# 4                1        INDIVIDUAL
# ...            ...               ...
# 54225            1        INDIVIDUAL
# 54226            1        INDIVIDUAL
# 54228            1        INDIVIDUAL
# 54229            1        INDIVIDUAL
# 54230            1        INDIVIDUAL
#
# [52336 rows x 29 columns]

# %%
# df.to_cv('transformed_loans.csv')
